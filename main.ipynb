# %%
import pandas as pd 
import matplotlib.pyplot as plt  
import numpy as np
import seaborn as sns
import plotly.express as ex

# %%
df = pd.read_csv(r'C:\Users\besha\OneDrive\Desktop\مشروع كلية\درجات الثانوية العامة.csv')

# %%
df.head(10)
# Out:
#    رقم الجلوس                           الاسم                         المدرسة  \
# 0      408000  روضه عمرو حلمى محمد انور شعلان  هيئة قناة السويس الخاصة ث لغات
# 1      408003    سما محمود اسماعيل السيد عطيه  هيئة قناة السويس الخاصة ث لغات
# 2      408004  شهد نادر عبدالفتاح عطا ابوشادى  هيئة قناة السويس الخاصة ث لغات
# 3      408008   لينه عوض صميده الحسينى الخولى  هيئة قناة السويس الخاصة ث لغات
# 4      408009          مريم انيس منصور اسكندر  هيئة قناة السويس الخاصة ث لغات
# 5      408010      ملك سيد محمد عبدالغنى محمد  هيئة قناة السويس الخاصة ث لغات
# 6      408016       رزان محمد سمير محمد توفيق  هيئة قناة السويس الخاصة ث لغات
# 7      408018     مريم اشرف ابراهيم الهم قرنى  هيئة قناة السويس الخاصة ث لغات
# 8      408020          هنا خالد احمد على احمد  هيئة قناة السويس الخاصة ث لغات
# 9      408024    عمر محمد عيد عبدالمجيد عليوة      فايد الثانوية الرسمية لغات
#
#   الأدارة التعليمية حالة الطالب      الشعبة اللغة العربية  \
# ...
